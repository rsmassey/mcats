# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
csv_path = "../data/raw/Ryan_small_30s.csv"
data = pd.read_csv(csv_path)
data
# Out:
#              filename     tempo  beats_mean  beats_var  zero_crossings_mean  \
# 0    hiphop.00023.wav -0.962068   -0.448284  -0.008626             0.071358
# 1    hiphop.00005.wav -1.692588   -0.312625   0.037037             0.501715
# 2    hiphop.00038.wav  2.325273    1.872180  -0.195345            -0.150793
# 3    hiphop.00089.wav  0.133712   -0.055590   0.511061             0.332044
# 4    hiphop.00011.wav  0.595093   -0.128534   0.325394            -0.228270
# ..                ...       ...         ...        ...                  ...
# 994  reggae.00077.wav  0.864232   -0.002215  -0.017949            -1.022971
# 995  reggae.00088.wav -0.414178    0.311060   0.462080             2.046657
# 996  reggae.00061.wav -0.962068   -0.200505   0.109352             0.715793
# 997  reggae.00009.wav  1.503438   -0.097230   0.087524            -1.030827
# 998  reggae.00036.wav -1.181224   -0.242533   0.243357            -1.063490
#
# ...

# %%
data  = data.drop("filename", axis=1)

# %%
data
# Out:
#         tempo  beats_mean  beats_var  zero_crossings_mean  zero_crossings_var  \
# 0   -0.962068   -0.448284  -0.008626             0.071358            0.127249
# 1   -1.692588   -0.312625   0.037037             0.501715            0.555764
# 2    2.325273    1.872180  -0.195345            -0.150793           -0.101815
# 3    0.133712   -0.055590   0.511061             0.332044            0.389219
# 4    0.595093   -0.128534   0.325394            -0.228270           -0.182964
# ..        ...         ...        ...                  ...                 ...
# 994  0.864232   -0.002215  -0.017949            -1.022971           -1.052920
# 995 -0.414178    0.311060   0.462080             2.046657            1.928526
# 996 -0.962068   -0.200505   0.109352             0.715793            0.761441
# 997  1.503438   -0.097230   0.087524            -1.030827           -1.061862
# 998 -1.181224   -0.242533   0.243357            -1.063490           -1.099112
#
# ...

# %%
# split the data into train and test
train_data, test_data = train_test_split(data, test_size=0.3)

# %%
train_data.to_csv('../data/raw/Ryan_train_small_30s.csv', index=False)
test_data.to_csv('../data/raw/Ryan_val_small_30s.csv', index=False)

# %%
import pandas as pd
d = pd.read_csv('../data/raw/Ryan_train_small_30s.csv')
d
# Out:
#         tempo  beats_mean  beats_var  zero_crossings_mean  zero_crossings_var  \
# 0   -0.414178   -0.078711   0.403383            -1.014262           -1.043014
# 1    0.864232    0.336270   0.748492             0.422496            0.478394
# 2   -1.075424    0.844073  -0.237260             0.741858            0.786143
# 3   -0.962068    0.326426   0.587410             1.816764            1.740656
# 4   -0.840314   -0.098432   0.659812             2.990491            2.639730
# ..        ...         ...        ...                  ...                 ...
# 694 -1.075424    0.099328   0.417054            -0.947277           -0.967105
# 695  0.352868    0.325687   0.858014             0.782626            0.824632
# 696  0.352868   -0.164811  -0.989788            -0.775603           -0.774781
# 697 -0.962068   -0.395828  -0.335439            -0.140735           -0.091329
# 698 -0.247429   -0.071348   0.486264            -0.307310           -0.266419
#
# ...
